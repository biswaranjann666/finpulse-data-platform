# %%
# %sql
CREATE CATALOG IF NOT EXISTS finpulse_dev
MANAGED LOCATION 'abfss://unity-catalog-root@stfinpulsedevuc01.dfs.core.windows.net/';

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS finpulse_dev.raw_landing;

# %%
# %sql
CREATE VOLUME IF NOT EXISTS finpulse_dev.raw_landing.source_files;

# %%
# %sql
LIST '/Volumes/finpulse_dev/raw_landing/source_files';
